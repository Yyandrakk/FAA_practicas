# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import Clasificador
import EstrategiaParticionado
from Datos import Datos
from plotModel import plotModel
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from IPython.display import HTML, display

# %% [markdown]
# # Practica 2
#
# Vamos a realizar un analisis de los algoritmos de clasificacion implementados, para ello vamos a mostrar los porcentajes de error de nuestra implementacion contra la de Sklearn utlizando validacion cruzada ya que como se demostro en la practica anterior se obtienen una representacion mas realista. Tambien vamos a mostrar unas graficas donde se mostraran las zonas de clasificacion de cada clase.
#
# ## Apartado 1
#
# ### Vecinos Proximos
#
# ##### Example1

# %%
salida = "<table><tr><th>K</th><th>Nuestro</th><th>Sklearn</th></tr>"
dataset = Datos('./ConjuntoDatos/example1.data')
encAtributos = preprocessing.OneHotEncoder(categorical_features=dataset.nominalAtributos[:-1], sparse=False)
X = encAtributos.fit_transform(dataset.datos[:, :-1])
Y = dataset.datos[:, -1]
estrategia = EstrategiaParticionado.ValidacionCruzada()

k = 1
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 3
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 5
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 11
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 21
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 51
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
display(HTML(salida))
# Out:
# <table><tr><th>K</th><th>Nuestro</th><th>Sklearn</th></tr><tr><td>1</td><td>0.1800 ± 0.052</td><td>0.1700 ± 0.062</td></tr><tr><td>3</td><td>0.1725 ± 0.051</td><td>0.1425 ± 0.064</td></tr><tr><td>5</td><td>0.1725 ± 0.049</td><td>0.1350 ± 0.058</td></tr><tr><td>11</td><td>0.1350 ± 0.055</td><td>0.1375 ± 0.050</td></tr><tr><td>21</td><td>0.1350 ± 0.041</td><td>0.1425 ± 0.073</td></tr><tr><td>51</td><td>0.1425 ± 0.037</td><td>0.1250 ± 0.049</td></tr>

# %% [markdown]
# Se puede ver que con el fichero Example1, nuestra tasa mínima de error es de 0.1350 con k = 11 y k = 21, contra 0.1250 de Sklearn con k = 21. Nuestra tasa máxima de error es de 0.180 con k = 1, contra 0.17 de Sklearn con k = 1.
#
# Si analizamos las gráficas, se puede ver que los puntos correspondientes a las esquinas de las gráficas están bien clasificados. Por contra, los puntos correspondientes al centro de la gráfica, no están del todo bien clasificados. Esto es debido a que hay varios puntos de distintas clases con una distancia muy cercana.
#
# ##### Example2

# %%
salida = "<table><tr><th>K</th><th>Nuestro</th><th>Sklearn</th></tr>"
dataset = Datos('./ConjuntoDatos/example2.data')
encAtributos = preprocessing.OneHotEncoder(categorical_features=dataset.nominalAtributos[:-1], sparse=False)
X = encAtributos.fit_transform(dataset.datos[:, :-1])
Y = dataset.datos[:, -1]
estrategia = EstrategiaParticionado.ValidacionCruzada()

k = 1
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 3
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 5
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 11
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 21
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 51
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
display(HTML(salida))
# Out:
# <table><tr><th>K</th><th>Nuestro</th><th>Sklearn</th></tr><tr><td>1</td><td>0.0000 ± 0.000</td><td>0.0000 ± 0.000</td></tr><tr><td>3</td><td>0.0000 ± 0.000</td><td>0.0000 ± 0.000</td></tr><tr><td>5</td><td>0.0000 ± 0.000</td><td>0.0000 ± 0.000</td></tr><tr><td>11</td><td>0.0000 ± 0.000</td><td>0.0000 ± 0.000</td></tr><tr><td>21</td><td>0.0000 ± 0.000</td><td>0.0000 ± 0.000</td></tr><tr><td>51</td><td>0.0000 ± 0.000</td><td>0.0000 ± 0.000</td></tr>

# %% [markdown]
# Se puede ver que con el fichero Example2, las tasas de error son de 0.
# Si analizamos las gráficas, se puede ver que todos los puntos de las clases están bastante alejados entre sí y sin posibilidad de que tengan una distancia cercana.
#
# ##### Example3

# %%
salida = "<table><tr><th>K</th><th>Nuestro</th><th>Sklearn</th></tr>"
dataset = Datos('./ConjuntoDatos/example3.data')
encAtributos = preprocessing.OneHotEncoder(categorical_features=dataset.nominalAtributos[:-1], sparse=False)
X = encAtributos.fit_transform(dataset.datos[:, :-1])
Y = dataset.datos[:, -1]
estrategia = EstrategiaParticionado.ValidacionCruzada()

k = 1
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 3
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 5
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 11
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 21
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 51
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
display(HTML(salida))
# Out:
# <table><tr><th>K</th><th>Nuestro</th><th>Sklearn</th></tr><tr><td>1</td><td>0.0250 ± 0.022</td><td>0.0275 ± 0.021</td></tr><tr><td>3</td><td>0.0300 ± 0.019</td><td>0.0375 ± 0.026</td></tr><tr><td>5</td><td>0.0300 ± 0.022</td><td>0.0325 ± 0.027</td></tr><tr><td>11</td><td>0.0200 ± 0.015</td><td>0.0225 ± 0.026</td></tr><tr><td>21</td><td>0.0300 ± 0.029</td><td>0.0300 ± 0.029</td></tr><tr><td>51</td><td>0.0200 ± 0.019</td><td>0.0300 ± 0.027</td></tr>

# %% [markdown]
# Con el fichero Example3, apreciamos que no hay mucha diferencia de error entre nuestra implementación y la de Sklearn, aun siendo mejor (por poco) o igual la nuestra. La tasa de error difiere entre las dos en un máximo de un 0.01 y podemos ver que son unas tasas de error bajas, entorno a 2% - 3%.
# Viendo las gráficas vemos que los puntos están puestos de una forma que no hay ninguno de otra clase con una distancia muy cercana. Con k = 1 se ve claramente que las fronteras están bien definidas y sólo hay problemas en los puntos en los que se quedan en la frontera.
#
# ##### Example4 (Normalizado)

# %%
salida = "<table><tr><th>K</th><th>Nuestro</th><th>Sklearn</th></tr>"
dataset = Datos('./ConjuntoDatos/example4.data')
encAtributos = preprocessing.OneHotEncoder(categorical_features=dataset.nominalAtributos[:-1], sparse=False)
X = encAtributos.fit_transform(dataset.datos[:, :-1])
Y = dataset.datos[:, -1]
estrategia = EstrategiaParticionado.ValidacionCruzada()

k = 1
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 3
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 5
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 11
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 21
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 51
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
display(HTML(salida))
# Out:
# <table><tr><th>K</th><th>Nuestro</th><th>Sklearn</th></tr><tr><td>1</td><td>0.0000 ± 0.000</td><td>0.0300 ± 0.046</td></tr><tr><td>3</td><td>0.0000 ± 0.000</td><td>0.0900 ± 0.094</td></tr><tr><td>5</td><td>0.0000 ± 0.000</td><td>0.1100 ± 0.104</td></tr><tr><td>11</td><td>0.0000 ± 0.000</td><td>0.2000 ± 0.077</td></tr><tr><td>21</td><td>0.0000 ± 0.000</td><td>0.3400 ± 0.120</td></tr><tr><td>51</td><td>0.0000 ± 0.000</td><td>0.5200 ± 0.189</td></tr>

# %% [markdown]
# Con las gráficas del fichero Example4 vemos que los puntos están paralelos y no hay puntos de distintas clases con una distancia cercana entre sí. Por eso nuestra implementación saca una tasa de error de 0. Por contra, la de sklearn, saca una tasa de error de hasta 0.52.
#
# ##### Example4 (No normalizado)

# %%
salida = "<table><tr><th>K</th><th>Nuestro</th><th>Sklearn</th></tr>"
dataset = Datos('./ConjuntoDatos/example4.data')
encAtributos = preprocessing.OneHotEncoder(categorical_features=dataset.nominalAtributos[:-1], sparse=False)
X = dataset.datos[:, :-1]
Y = dataset.datos[:, -1]
estrategia = EstrategiaParticionado.ValidacionCruzada()

k = 1
clasificador = Clasificador.ClasificadorVecinosProximos(k, False)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 3
clasificador = Clasificador.ClasificadorVecinosProximos(k, False)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 5
clasificador = Clasificador.ClasificadorVecinosProximos(k, False)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 11
clasificador = Clasificador.ClasificadorVecinosProximos(k, False)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 21
clasificador = Clasificador.ClasificadorVecinosProximos(k, False)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
k = 51
clasificador = Clasificador.ClasificadorVecinosProximos(k, False)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "KNN K="+str(k), dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
display(HTML(salida))
# Out:
# <table><tr><th>K</th><th>Nuestro</th><th>Sklearn</th></tr><tr><td>1</td><td>0.0300 ± 0.046</td><td>0.0300 ± 0.046</td></tr><tr><td>3</td><td>0.1000 ± 0.089</td><td>0.0900 ± 0.094</td></tr><tr><td>5</td><td>0.1000 ± 0.077</td><td>0.1100 ± 0.104</td></tr><tr><td>11</td><td>0.2200 ± 0.098</td><td>0.2000 ± 0.077</td></tr><tr><td>21</td><td>0.3800 ± 0.166</td><td>0.3400 ± 0.120</td></tr><tr><td>51</td><td>0.5400 ± 0.156</td><td>0.5200 ± 0.189</td></tr>

# %% [markdown]
# Hay una diferencia bastante notable con los datos normalizados y sin normalizar. Por ejemplo, con k = 51 el aumento en la tasa de error es de 0.54, cuando anteriormente era de 0. Con el resto de k pasa lo mismo, la tasa de error ha aumentado. Esto es debido a que los valores de una clase pueden ser mucho mayores respecto a los de la otra, por lo tanto, las distancias aumentan y la clasificación empeora.
#
# ##### wdbc (Normalizado)

# %%
salida = "<table><tr><th>K</th><th>Nuestro</th><th>Sklearn</th></tr>"
dataset = Datos('./ConjuntoDatos/wdbc.data')
encAtributos = preprocessing.OneHotEncoder(categorical_features=dataset.nominalAtributos[:-1], sparse=False)
X = encAtributos.fit_transform(dataset.datos[:, :-1])
Y = dataset.datos[:, -1]
estrategia = EstrategiaParticionado.ValidacionCruzada()

k = 1
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
k = 3
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
k = 5
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
k = 11
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
k = 21
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
k = 51
clasificador = Clasificador.ClasificadorVecinosProximos(k)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
display(HTML(salida))
# Out:
# <table><tr><th>K</th><th>Nuestro</th><th>Sklearn</th></tr><tr><td>1</td><td>0.0500 ± 0.034</td><td>0.0842 ± 0.030</td></tr><tr><td>3</td><td>0.0286 ± 0.023</td><td>0.0737 ± 0.030</td></tr><tr><td>5</td><td>0.0268 ± 0.016</td><td>0.0702 ± 0.029</td></tr><tr><td>11</td><td>0.0268 ± 0.018</td><td>0.0700 ± 0.036</td></tr><tr><td>21</td><td>0.0375 ± 0.023</td><td>0.0700 ± 0.034</td></tr><tr><td>51</td><td>0.0518 ± 0.027</td><td>0.0823 ± 0.032</td></tr>

# %% [markdown]
# Este es el fichero con más datos de la práctica. Los ficheros ExampleX están compuestos por 400 filas y cada fila con dos atributos más la clase. Este fichero está compuesto por 569 filas y 30 atributos más la clase. Por eso, deducimos que este es el fichero que más validez tiene a la hora de comprobar la tasa de error.
#
# Vemos que nuestra implementación responde bastante bien, con valores entre 0.026 y 0.052 de tasa de error. Sklearn tiene una tasa más alta, entre 0.07 y 0.084.
#
# Por estos datos, deducimos que nuestra implementación está bastante lograda.

# %% [markdown]
# ##### wdbc (No normalizado)

# %%
salida = "<table><tr><th>K</th><th>Nuestro</th><th>Sklearn</th></tr>"
dataset = Datos('./ConjuntoDatos/wdbc.data')
encAtributos = preprocessing.OneHotEncoder(categorical_features=dataset.nominalAtributos[:-1], sparse=False)
X = dataset.datos[:, :-1]
Y = dataset.datos[:, -1]
estrategia = EstrategiaParticionado.ValidacionCruzada()

k = 1
clasificador = Clasificador.ClasificadorVecinosProximos(k, False)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
k = 3
clasificador = Clasificador.ClasificadorVecinosProximos(k, False)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
k = 5
clasificador = Clasificador.ClasificadorVecinosProximos(k, False)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
k = 11
clasificador = Clasificador.ClasificadorVecinosProximos(k, False)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
k = 21
clasificador = Clasificador.ClasificadorVecinosProximos(k, False)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
k = 51
clasificador = Clasificador.ClasificadorVecinosProximos(k, False)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = KNeighborsClassifier(n_neighbors=k, p=2, metric='euclidean')
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>" + str(k) + "</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
display(HTML(salida))
# Out:
# <table><tr><th>K</th><th>Nuestro</th><th>Sklearn</th></tr><tr><td>1</td><td>0.0821 ± 0.037</td><td>0.0842 ± 0.030</td></tr><tr><td>3</td><td>0.0786 ± 0.029</td><td>0.0737 ± 0.030</td></tr><tr><td>5</td><td>0.0679 ± 0.036</td><td>0.0702 ± 0.029</td></tr><tr><td>11</td><td>0.0661 ± 0.037</td><td>0.0700 ± 0.036</td></tr><tr><td>21</td><td>0.0714 ± 0.043</td><td>0.0700 ± 0.034</td></tr><tr><td>51</td><td>0.0786 ± 0.035</td><td>0.0823 ± 0.032</td></tr>

# %% [markdown]
# Ejecutando knn sin normalizar, podemos comprobar que la solución de sklearn no modifica su tasa de error, por lo tanto no le afecta la normalización de los datos. Nuestra implementación si aumenta la tasa de error, con un aumento de un 0.03, más o menos.
#
#
# ## Apartado 2
#
# ### Regresion Logistica
#
# ##### Example1

# %%
salida = "<table><tr><th>C.Aprendizaje/Epocas</th><th>Nuestro</th><th>Sklearn</th></tr>"
dataset = Datos('./ConjuntoDatos/example1.data')
encAtributos = preprocessing.OneHotEncoder(categorical_features=dataset.nominalAtributos[:-1], sparse=False)
X = encAtributos.fit_transform(dataset.datos[:, :-1])
Y = dataset.datos[:, -1]
estrategia = EstrategiaParticionado.ValidacionCruzada()


clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=10,consApren=1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=10)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>1/10</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=1;EPOC=10", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=100,consApren=1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=100)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>1/100</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=1;EPOC=100", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=1000,consApren=1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=1000)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>1/1000</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=1;EPOC=1000", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=10,consApren=0.1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=10)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.1/10</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.1;EPOC=10", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=100,consApren=0.1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=100)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.1/100</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.1;EPOC=100", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=1000,consApren=0.1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=1000)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.1/1000</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.1;EPOC=1000", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=10,consApren=0.01)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=10)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.01/10</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.01;EPOC=10", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=100,consApren=0.01)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=100)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.01/100</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.01;EPOC=100", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=1000,consApren=0.01)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=1000)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.01/1000</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr></table>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.01;EPOC=1000", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %% [markdown]
# Hasta ahora hemos visto la evolucion de las graficas segun se iban variando las graficas segun los parametros de Epoca y constante de aprendizaje, y ahora vamos a mostrar una tabla donde se recogen los distintos niveles de error.
#
# Huelga recordar que al usar validacion cruzada se nos generan en este caso 10 conjuntos de Train y Test por tanto el dibujado es el ultimo y no tiene que corresponder con la mejor ni peor de los casos, hemos decidido no imprimir los 10 conjuntos ya que el notebook se haria demasiado largo y lo importante se ve en la tabla siguiente.

# %%
display(HTML(salida))
# Out:
# <table><tr><th>C.Aprendizaje/Epocas</th><th>Nuestro</th><th>Sklearn</th></tr><tr><td>1/10</td><td>0.5250 ± 0.050</td><td>0.5625 ± 0.049</td></tr><tr><td>1/100</td><td>0.5250 ± 0.050</td><td>0.5625 ± 0.049</td></tr><tr><td>1/1000</td><td>0.5250 ± 0.050</td><td>0.5625 ± 0.049</td></tr><tr><td>0.1/10</td><td>0.5200 ± 0.040</td><td>0.5625 ± 0.049</td></tr><tr><td>0.1/100</td><td>0.5200 ± 0.040</td><td>0.5625 ± 0.049</td></tr><tr><td>0.1/1000</td><td>0.5200 ± 0.040</td><td>0.5625 ± 0.049</td></tr><tr><td>0.01/10</td><td>0.5214 ± 0.064</td><td>0.5625 ± 0.049</td></tr><tr><td>0.01/100</td><td>0.5044 ± 0.047</td><td>0.5625 ± 0.049</td></tr><tr><td>0.01/1000</td><td>0.5050 ± 0.047</td><td>0.5625 ± 0.049</td></tr></table>

# %% [markdown]
# Como se puede apreciar skelearn da siempre el mismo valor, esto es porque la funcion proporcionada no tiene Constante de aprendizaje por tanto solo se pueden variar las epocas que no influyen.
#
# Segun los datos nuestro algoritmo tiene una tasa de error menor que sklearn en general, pero podemos comprobar que cuanto mas baja en la C. Aprendizaje mas bajo es el error, lo que tiene su logica ya que afinamos el movimiento de la recta mas lentamente lo que tambien hace mas necesario un mayor numero de epocas, viendo nuestro mejor resultado en 0.01/100.
#
# La tasa de error tiende al 50% lo que tiene su logica ya que los datos se mezclan formando una cruz lo que hace imposible que una recta divida la zona en dos regiones perfectas.
#
# #### Expample 2

# %%
salida = "<table><tr><th>C.Aprendizaje/Epocas</th><th>Nuestro</th><th>Sklearn</th></tr>"
dataset = Datos('./ConjuntoDatos/example2.data')
encAtributos = preprocessing.OneHotEncoder(categorical_features=dataset.nominalAtributos[:-1], sparse=False)
X = encAtributos.fit_transform(dataset.datos[:, :-1])
Y = dataset.datos[:, -1]
estrategia = EstrategiaParticionado.ValidacionCruzada()


clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=10,consApren=1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,1)
clf = LogisticRegression(max_iter=10)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>1/10</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=1;EPOC=10", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=100,consApren=1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,1)
clf = LogisticRegression(max_iter=100)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>1/100</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=1;EPOC=100", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=1000,consApren=1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,1)
clf = LogisticRegression(max_iter=1000)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>1/1000</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=1;EPOC=1000", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=10,consApren=0.1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,1)
clf = LogisticRegression(max_iter=10)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.1/10</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.1;EPOC=10", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=100,consApren=0.1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,1)
clf = LogisticRegression(max_iter=100)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.1/100</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.1;EPOC=100", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=1000,consApren=0.1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,1)
clf = LogisticRegression(max_iter=1000)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.1/1000</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.1;EPOC=1000", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=10,consApren=0.01)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,1)
clf = LogisticRegression(max_iter=10)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.01/10</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.01;EPOC=10", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=100,consApren=0.01)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,1)
clf = LogisticRegression(max_iter=100)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.01/100</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.01;EPOC=100", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=1000,consApren=0.01)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,1)
clf = LogisticRegression(max_iter=1000)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.01/1000</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr></table>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.01;EPOC=1000", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %% [markdown]
# Las graficas mostradas para este ejemplo es una puerta logica XOR, pero no son exactamente 4 puntos como se puede pensar en la grafica, ya que N puntos sobrepuestos.

# %%
display(HTML(salida))
# Out:
# <table><tr><th>C.Aprendizaje/Epocas</th><th>Nuestro</th><th>Sklearn</th></tr><tr><td>1/10</td><td>0.2500 ± 0.067</td><td>0.5500 ± 0.124</td></tr><tr><td>1/100</td><td>0.2500 ± 0.067</td><td>0.5500 ± 0.124</td></tr><tr><td>1/1000</td><td>0.2500 ± 0.067</td><td>0.5500 ± 0.124</td></tr><tr><td>0.1/10</td><td>0.5200 ± 0.075</td><td>0.5500 ± 0.124</td></tr><tr><td>0.1/100</td><td>0.5200 ± 0.075</td><td>0.5500 ± 0.124</td></tr><tr><td>0.1/1000</td><td>0.5200 ± 0.075</td><td>0.5500 ± 0.124</td></tr><tr><td>0.01/10</td><td>0.5275 ± 0.139</td><td>0.5500 ± 0.124</td></tr><tr><td>0.01/100</td><td>0.5325 ± 0.153</td><td>0.5500 ± 0.124</td></tr><tr><td>0.01/1000</td><td>0.5325 ± 0.153</td><td>0.5500 ± 0.124</td></tr></table>

# %% [markdown]
# En este ejemplo pasa justamente lo contrario, cuanto mas baja es la constante mas error producimos pero siempre debajo de sklearn.
#
# Con constante a 1, llegamos al error minimo que puede obtener regresion logistica para el problema de la puerta logica XOR como ya vimos en teoria. Que con constantes mas bajas de un error mayor puede deberse a que necesite un mayor numero de epocas para llegar a una solucion.
#
# #### Example 3

# %%
salida = "<table><tr><th>C.Aprendizaje/Epocas</th><th>Nuestro</th><th>Sklearn</th></tr>"
dataset = Datos('./ConjuntoDatos/example3.data')
encAtributos = preprocessing.OneHotEncoder(categorical_features=dataset.nominalAtributos[:-1], sparse=False)
X = encAtributos.fit_transform(dataset.datos[:, :-1])
Y = dataset.datos[:, -1]
estrategia = EstrategiaParticionado.ValidacionCruzada()


clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=10,consApren=1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=10)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>1/10</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=1;EPOC=10", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=100,consApren=1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=100)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>1/100</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=1;EPOC=100", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=1000,consApren=1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=1000)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>1/1000</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=1;EPOC=1000", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=10,consApren=0.1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=10)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.1/10</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.1;EPOC=10", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=100,consApren=0.1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=100)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.1/100</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.1;EPOC=100", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=1000,consApren=0.1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=1000)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.1/1000</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.1;EPOC=1000", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=10,consApren=0.01)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=10)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.01/10</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.01;EPOC=10", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=100,consApren=0.01)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=100)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.01/100</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.01;EPOC=100", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=1000,consApren=0.01)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=1000)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.01/1000</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr></table>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.01;EPOC=1000", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %% [markdown]
# La grafica muestra 4 zonas con los de misma clase en diagonal

# %%
display(HTML(salida))
# Out:
# <table><tr><th>C.Aprendizaje/Epocas</th><th>Nuestro</th><th>Sklearn</th></tr><tr><td>1/10</td><td>0.4900 ± 0.058</td><td>0.5350 ± 0.069</td></tr><tr><td>1/100</td><td>0.4937 ± 0.056</td><td>0.5350 ± 0.069</td></tr><tr><td>1/1000</td><td>0.5067 ± 0.069</td><td>0.5350 ± 0.069</td></tr><tr><td>0.1/10</td><td>0.4800 ± 0.066</td><td>0.5350 ± 0.069</td></tr><tr><td>0.1/100</td><td>0.4800 ± 0.066</td><td>0.5350 ± 0.069</td></tr><tr><td>0.1/1000</td><td>0.4800 ± 0.066</td><td>0.5350 ± 0.069</td></tr><tr><td>0.01/10</td><td>0.5000 ± 0.077</td><td>0.5350 ± 0.069</td></tr><tr><td>0.01/100</td><td>0.5000 ± 0.077</td><td>0.5350 ± 0.069</td></tr><tr><td>0.01/1000</td><td>0.5000 ± 0.077</td><td>0.5350 ± 0.069</td></tr></table>

# %% [markdown]
# Como se puede apreciar el mejor resultado, se da cuando la constante es 0.1 y las epocas no influyen en el resultado, o el numero de epocas es demasidado pequeño para empezar a influir en el caso de la constante mas pequeñas.
#
# Como se puede apreciar el resultado de error tiende al 50% lo que es comprensible ya que con una sola recta no es posible partir la grafica sin dejar elementos de la otra clase.
#
# #### Example 4

# %%
salida = "<table><tr><th>C.Aprendizaje/Epocas</th><th>Nuestro</th><th>Sklearn</th></tr>"
dataset = Datos('./ConjuntoDatos/example4.data')
encAtributos = preprocessing.OneHotEncoder(categorical_features=dataset.nominalAtributos[:-1], sparse=False)
X = encAtributos.fit_transform(dataset.datos[:, :-1])
Y = dataset.datos[:, -1]
estrategia = EstrategiaParticionado.ValidacionCruzada()


clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=10,consApren=1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=10)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>1/10</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=1;EPOC=10", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=100,consApren=1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=100)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>1/100</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=1;EPOC=100", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=1000,consApren=1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=1000)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>1/1000</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=1;EPOC=1000", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=10,consApren=0.1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=10)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.1/10</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.1;EPOC=10", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=100,consApren=0.1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=100)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.1/100</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.1;EPOC=100", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=1000,consApren=0.1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=1000)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.1/1000</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.1;EPOC=1000", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=10,consApren=0.01)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=10)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.01/10</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.01;EPOC=10", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=100,consApren=0.01)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=100)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.01/100</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.01;EPOC=100", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=1000,consApren=0.01)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=1000)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.01/1000</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr></table>" % (error_media_sk,error_std_sk)

ii = estrategia.particiones[-1].indicesTrain
plotModel(dataset.datos[ii, 0], dataset.datos[ii, 1], dataset.datos[ii, -1] != 0, clasificador, "RL LR=0.01;EPOC=1000", dataset.diccionarios)
plt.plot(dataset.datos[dataset.datos[:,-1]==0,0],dataset.datos[dataset.datos[:,-1]==0,1],'ro')
plt.plot(dataset.datos[dataset.datos[:,-1]==1,0],dataset.datos[dataset.datos[:,-1]==1,1],'bo')
plt.show()

# %% [markdown]
# Los puntos forman dos rectas paralelas, cada recta es para una clase por tanto es el clasificador mas indicado ya que va seccionar en dos zonas perfectas

# %%
display(HTML(salida))
# Out:
# <table><tr><th>C.Aprendizaje/Epocas</th><th>Nuestro</th><th>Sklearn</th></tr><tr><td>1/10</td><td>0.0000 ± 0.000</td><td>0.0000 ± 0.000</td></tr><tr><td>1/100</td><td>0.0000 ± 0.000</td><td>0.0000 ± 0.000</td></tr><tr><td>1/1000</td><td>0.0000 ± 0.000</td><td>0.0000 ± 0.000</td></tr><tr><td>0.1/10</td><td>0.0000 ± 0.000</td><td>0.0000 ± 0.000</td></tr><tr><td>0.1/100</td><td>0.0000 ± 0.000</td><td>0.0000 ± 0.000</td></tr><tr><td>0.1/1000</td><td>0.0000 ± 0.000</td><td>0.0000 ± 0.000</td></tr><tr><td>0.01/10</td><td>0.0757 ± 0.173</td><td>0.0000 ± 0.000</td></tr><tr><td>0.01/100</td><td>0.0000 ± 0.000</td><td>0.0000 ± 0.000</td></tr><tr><td>0.01/1000</td><td>0.0000 ± 0.000</td><td>0.0000 ± 0.000</td></tr></table>

# %% [markdown]
# Como era de esperar el error es 0% porque las clases estaban muy diferencidad, pero tambien sirve para ver el efecto de la constante de aprendizaje y el numero de epocas, ya que con 0.01/10 si da tasa de error ya que la recta se mueve mas lenta y necesita mas epocas para poder llegar a una recta solucion.
#
# #### wdbc

# %%
salida = "<table><tr><th>C.Aprendizaje/Epocas</th><th>Nuestro</th><th>Sklearn</th></tr>"
dataset = Datos('./ConjuntoDatos/wdbc.data')
encAtributos = preprocessing.OneHotEncoder(categorical_features=dataset.nominalAtributos[:-1], sparse=False)
X = encAtributos.fit_transform(dataset.datos[:, :-1])
Y = dataset.datos[:, -1]
estrategia = EstrategiaParticionado.ValidacionCruzada()


clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=10,consApren=1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=10)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>1/10</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=100,consApren=1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=100)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>1/100</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=1000,consApren=1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=1000)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>1/1000</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=10,consApren=0.1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=10)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.1/10</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=100,consApren=0.1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=100)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.1/100</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=1000,consApren=0.1)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=1000)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.1/1000</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=10,consApren=0.01)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=10)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.01/10</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=100,consApren=0.01)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=100)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.01/100</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr>" % (error_media_sk,error_std_sk)

# %%
clasificador = Clasificador.ClasificadorRegresionLogistica(nEpoc=1000,consApren=0.01)
error_media, error_std = clasificador.validacion(estrategia, dataset, clasificador,45)
clf = LogisticRegression(max_iter=1000)
score = cross_val_score(clf, X, Y, cv=10,n_jobs=-1)
error_media_sk = 1 - score.mean()
error_std_sk = score.std()

salida += "<tr><td>0.01/1000</td>"
salida += "<td>%.4f ± %.3f</td>" % (error_media,error_std)
salida += "<td>%.4f ± %.3f</td></tr></table>" % (error_media_sk,error_std_sk)

# %%
display(HTML(salida))
# Out:
# <table><tr><th>C.Aprendizaje/Epocas</th><th>Nuestro</th><th>Sklearn</th></tr><tr><td>1/10</td><td>0.1607 ± 0.112</td><td>0.0720 ± 0.023</td></tr><tr><td>1/100</td><td>0.0929 ± 0.040</td><td>0.0491 ± 0.019</td></tr><tr><td>1/1000</td><td>0.0815 ± 0.042</td><td>0.0491 ± 0.019</td></tr><tr><td>0.1/10</td><td>0.1629 ± 0.118</td><td>0.0720 ± 0.023</td></tr><tr><td>0.1/100</td><td>0.1046 ± 0.049</td><td>0.0491 ± 0.019</td></tr><tr><td>0.1/1000</td><td>0.0860 ± 0.046</td><td>0.0491 ± 0.019</td></tr><tr><td>0.01/10</td><td>0.1436 ± 0.102</td><td>0.0720 ± 0.023</td></tr><tr><td>0.01/100</td><td>0.1042 ± 0.046</td><td>0.0491 ± 0.019</td></tr><tr><td>0.01/1000</td><td>0.0846 ± 0.046</td><td>0.0491 ± 0.019</td></tr></table>

# %% [markdown]
# Este es el unico archivo en el que nuestra implementacion es peor que la de Sklearn, esto puede ser que tengan mayor precision al calcular la funcion sigmoidal cuando el exponente es muy grande. Tambien podemos apreciar que un mayor numero epocas si influye en un mejor resultado final, siendo 100 para Skearn y mas de 1000 en el nuestro ya que parece que sigue mejorando cuentas mas epocas.
